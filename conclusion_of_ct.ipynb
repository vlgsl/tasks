# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/data2.csv')

# %%
df.info()

# %%
import nltk
nltk.download('stopwords')
nltk_words = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['Conclusion_without_stopwords'] = df['Conclusion'].apply(lambda x: ' '.join([word for word in x.split() if word not in (nltk_words)]))
df['Conclusion_without_stopwords'] = df['Conclusion_without_stopwords'].str.replace('[^\w\s]','')

# %%
a = pd.Series(' '.join(df['Conclusion_without_stopwords']).lower().split()).value_counts()[:100]

# %%
a
# Out:
# изменений         307
# типу              294
# воспалительных    292
# могут             292
# вероятности       291
#                  ...
# кистоподобные       7
# увеличение          7
# легком              7
# наличие             6
# узелковые           6
# Length: 100, dtype: int64

# %%
pd.DataFrame(a).plot.bar()

# %%
pip install wordcloud

# %%
from wordcloud import WordCloud
wc = WordCloud(width=800, height=400, max_words=200).generate_from_frequencies(a)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
